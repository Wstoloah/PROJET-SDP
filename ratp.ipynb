# %%
import pandas as pd

data = pd.read_csv('ratp.csv')
display(data)
# Out:
#    peak-entering-passengers/h  peak-passing-passengers/h  \
# 0                       85000                       8100
# 1                       81000                       8100
# 2                       74000                       8900
# 3                       74000                       7100
# 4                       72000                       7500
# 5                       71000                       7300
# 6                       79000                       6900
# 7                       57000                       7600
# 8                       84000                       7900
# 9                       72000                       8700
#
#    off-peak-entering-passengers/h  off-peak-passing-passengers/h  \
# 0                           35500                           3450
# 1                           37500                           3150
# 2                           37000                           4050
# 3                           42000                           4550
# 4                           33000                           4250
# 5                           31500                           4600
# 6                           39000                           3800
# 7                           40500                           3800
# 8                           34000                           3300
# 9                           36000                           4000
#
#    strategic priority [0,10]  Station degradation level ([0,20]  scale)  \
# 0                         75                                       16.2
# 1                         67                                       17.6
# 2                         68                                       16.8
# 3                         77                                       15.2
# 4                         88                                       13.2
# 5                         76                                       15.8
# 6                         67                                       16.8
# 7                         82                                       17.2
# 8                         74                                       15.8
# 9                         66                                       16.6
#
#    connectivity index [0,100]                                  name
# 0                          88                       Odéon (Ligne 4)
# 1                          95               Place d'Italie (Lign 6)
# 2                          79                     Jussieu (Ligne 7)
# 3                          73                      Nation (Ligne 9)
# 4                          93  La Motte Picquet-Grenelle (Ligne 10)
# 5                          93             Porte d'Orléans (Ligne 4)
# 6                          79                    Daumenil (Ligne 6)
# 7                          77                  Vaugirard (Ligne 12)
# 8                          85                   Oberkampf (Ligne 9)
# 9                          78             Reuilly-Diderot (Ligne 1)

# %%
WEIGHTS = [0.021, 0.188, 0.038, 0.322, 16.124, 67.183, 16.124]

def score(row):
    s = 0
    for i, w in enumerate(WEIGHTS):
        s += row.iloc[i] * w
    return s

data['score'] = data.apply(lambda row: score(row), axis=1)

# sort by score descending
data = data.sort_values(by='score', ascending=False)
display(data[['score'] + list(data.columns[:-1])])
# Out:
#        score  peak-entering-passengers/h  peak-passing-passengers/h  \
# 0  9484.2766                       85000                       8100
# 1  9457.6088                       81000                       8100
# 2  9436.2024                       74000                       8900
# 3  9389.6816                       74000                       7100
# 4  9349.7596                       72000                       7500
# 5  9328.0474                       71000                       7300
# 9  9240.6938                       72000                       8700
# 8  9229.0074                       84000                       7900
# 6  9144.5784                       79000                       6900
# 7  9107.6636                       57000                       7600
#
#    off-peak-entering-passengers/h  off-peak-passing-passengers/h  \
# 0                           35500                           3450
# 1                           37500                           3150
# 2                           37000                           4050
# 3                           42000                           4550
# 4                           33000                           4250
# 5                           31500                           4600
# 9                           36000                           4000
# 8                           34000                           3300
# 6                           39000                           3800
# 7                           40500                           3800
#
#    strategic priority [0,10]  Station degradation level ([0,20]  scale)  \
# 0                         75                                       16.2
# 1                         67                                       17.6
# 2                         68                                       16.8
# 3                         77                                       15.2
# 4                         88                                       13.2
# 5                         76                                       15.8
# 9                         66                                       16.6
# 8                         74                                       15.8
# 6                         67                                       16.8
# 7                         82                                       17.2
#
#    connectivity index [0,100]                                  name
# 0                          88                       Odéon (Ligne 4)
# 1                          95               Place d'Italie (Lign 6)
# 2                          79                     Jussieu (Ligne 7)
# 3                          73                      Nation (Ligne 9)
# 4                          93  La Motte Picquet-Grenelle (Ligne 10)
# 5                          93             Porte d'Orléans (Ligne 4)
# 9                          78             Reuilly-Diderot (Ligne 1)
# 8                          85                   Oberkampf (Ligne 9)
# 6                          79                    Daumenil (Ligne 6)
# 7                          77                  Vaugirard (Ligne 12)

# %%
def get_record(data, index):
    return data.iloc[index].tolist()[:-2]

def get_two_consecutive_records(data):
    for i in range(len(data) - 1):
        yield data.iloc[i].tolist()[:-2], data.iloc[i + 1].tolist()[:-2]    

# map: record(tuple) -> name
record_dict = {}
for i in range(len(data)):
    record = get_record(data, i)
    record_dict[tuple(record)] = data.iloc[i]['name']

# %%
ONE_TO_MANY_EXPLAINED = 0
MANY_TO_ONE_EXPLAINED = 0
COMBINED_EXPLAINED = 0

EXPLANATION_TYPES = ["1-m", "m-1", ["1-m", "m-1"]]

INFEASIBLE_RECORDS = []


from script import find_explanation

for record1, record2 in get_two_consecutive_records(data):

    for explanation_type in EXPLANATION_TYPES:
        explanation = find_explanation(record1, record2, explanation_type, verbose=False)
        if explanation_type == "1-m" and explanation["status"] != "infeasible":
            ONE_TO_MANY_EXPLAINED += 1
        elif explanation_type == "m-1" and explanation["status"] != "infeasible":
            MANY_TO_ONE_EXPLAINED += 1
        elif explanation_type == ["1-m", "m-1"] and explanation["status"] != "infeasible":
            COMBINED_EXPLAINED += 1
        else:
            INFEASIBLE_RECORDS.append((record1, record2, explanation_type))


print(f"One-to-Many Explained: {ONE_TO_MANY_EXPLAINED / 10 * 100}%")
print(f"Many-to-One Explained: {MANY_TO_ONE_EXPLAINED / 10 * 100}%")
print(f"Combined Explained: {COMBINED_EXPLAINED / 10 * 100}%")
print("=" * 40)
print(f"Infeasible Records: {len(INFEASIBLE_RECORDS)}")
for rec1, rec2, expl_type in INFEASIBLE_RECORDS:
    print(f"Record1: {rec1}")
    print(f"Record2: {rec2}")
    print(f"Explanation Type: {expl_type}")
    print("-" * 40)
# Out:
# One-to-Many Explained: 20.0%
# Many-to-One Explained: 30.0%
# Combined Explained: 50.0%
# ========================================
# Infeasible Records: 17
# Record1: [81000.0, 8100.0, 37500.0, 3150.0, 67.0, 17.6, 95.0]
# Record2: [74000.0, 8900.0, 37000.0, 4050.0, 68.0, 16.8, 79.0]
# Explanation Type: 1-m
# ----------------------------------------
# Record1: [81000.0, 8100.0, 37500.0, 3150.0, 67.0, 17.6, 95.0]
# Record2: [74000.0, 8900.0, 37000.0, 4050.0, 68.0, 16.8, 79.0]
# Explanation Type: m-1
# ----------------------------------------
# Record1: [81000.0, 8100.0, 37500.0, 3150.0, 67.0, 17.6, 95.0]
# Record2: [74000.0, 8900.0, 37000.0, 4050.0, 68.0, 16.8, 79.0]
# Explanation Type: ['1-m', 'm-1']
# ----------------------------------------
# Record1: [74000.0, 8900.0, 37000.0, 4050.0, 68.0, 16.8, 79.0]
# Record2: [74000.0, 7100.0, 42000.0, 4550.0, 77.0, 15.2, 73.0]
# Explanation Type: 1-m
# ----------------------------------------
# Record1: [74000.0, 8900.0, 37000.0, 4050.0, 68.0, 16.8, 79.0]
# Record2: [74000.0, 7100.0, 42000.0, 4550.0, 77.0, 15.2, 73.0]
# Explanation Type: m-1
# ----------------------------------------
# Record1: [74000.0, 7100.0, 42000.0, 4550.0, 77.0, 15.2, 73.0]
# Record2: [72000.0, 7500.0, 33000.0, 4250.0, 88.0, 13.2, 93.0]
# Explanation Type: 1-m
# ----------------------------------------
# Record1: [74000.0, 7100.0, 42000.0, 4550.0, 77.0, 15.2, 73.0]
# Record2: [72000.0, 7500.0, 33000.0, 4250.0, 88.0, 13.2, 93.0]
# Explanation Type: m-1
# ----------------------------------------
# Record1: [74000.0, 7100.0, 42000.0, 4550.0, 77.0, 15.2, 73.0]
# Record2: [72000.0, 7500.0, 33000.0, 4250.0, 88.0, 13.2, 93.0]
# Explanation Type: ['1-m', 'm-1']
# ----------------------------------------
# Record1: [72000.0, 7500.0, 33000.0, 4250.0, 88.0, 13.2, 93.0]
# Record2: [71000.0, 7300.0, 31500.0, 4600.0, 76.0, 15.8, 93.0]
# Explanation Type: 1-m
# ----------------------------------------
# Record1: [71000.0, 7300.0, 31500.0, 4600.0, 76.0, 15.8, 93.0]
# Record2: [72000.0, 8700.0, 36000.0, 4000.0, 66.0, 16.6, 78.0]
# Explanation Type: 1-m
# ----------------------------------------
# Record1: [71000.0, 7300.0, 31500.0, 4600.0, 76.0, 15.8, 93.0]
# Record2: [72000.0, 8700.0, 36000.0, 4000.0, 66.0, 16.6, 78.0]
# Explanation Type: m-1
# ----------------------------------------
# Record1: [71000.0, 7300.0, 31500.0, 4600.0, 76.0, 15.8, 93.0]
# Record2: [72000.0, 8700.0, 36000.0, 4000.0, 66.0, 16.6, 78.0]
# Explanation Type: ['1-m', 'm-1']
# ----------------------------------------
# Record1: [72000.0, 8700.0, 36000.0, 4000.0, 66.0, 16.6, 78.0]
# Record2: [84000.0, 7900.0, 34000.0, 3300.0, 74.0, 15.8, 85.0]
# Explanation Type: 1-m
# ----------------------------------------
# Record1: [72000.0, 8700.0, 36000.0, 4000.0, 66.0, 16.6, 78.0]
# Record2: [84000.0, 7900.0, 34000.0, 3300.0, 74.0, 15.8, 85.0]
# Explanation Type: m-1
# ----------------------------------------
# Record1: [72000.0, 8700.0, 36000.0, 4000.0, 66.0, 16.6, 78.0]
# Record2: [84000.0, 7900.0, 34000.0, 3300.0, 74.0, 15.8, 85.0]
# Explanation Type: ['1-m', 'm-1']
# ----------------------------------------
# Record1: [84000.0, 7900.0, 34000.0, 3300.0, 74.0, 15.8, 85.0]
# Record2: [79000.0, 6900.0, 39000.0, 3800.0, 67.0, 16.8, 79.0]
# Explanation Type: 1-m
# ----------------------------------------
# Record1: [79000.0, 6900.0, 39000.0, 3800.0, 67.0, 16.8, 79.0]
# Record2: [57000.0, 7600.0, 40500.0, 3800.0, 82.0, 17.2, 77.0]
# Explanation Type: m-1
# ----------------------------------------

# %%
from script import find_explanation

for record1, record2 in get_two_consecutive_records(data):

    explanation = find_explanation(record1, record2)
    print(f"Explanation: {explanation}")
    print("-" * 40)
    break
# Out:
# ================================================================================
# WEIGHTED CONTRIBUTION TABLE (Record 1 - Record 2)
# ================================================================================
# |   A    |   B    |   C    |   D    |   E    |   F    |   G    |
# |---------|---------|---------|---------|---------|---------|---------|
# | +84.000 |  +0.000 | -76.000 | +96.600 | +128.992 | -94.056 | -112.868 |
# |---------|---------|---------|---------|---------|---------|---------|
#
# Total weighted difference: +26.668
# [✓] Record 1 is preferred to Record 2 (positive total)
#
# ================================================================================
# PROS AND CONS ANALYSIS
# ================================================================================
#
# Pros (positive contributions):
#   A: +84.000
#   D: +96.600
#   E: +128.992
#
# Cons (negative contributions):
#   C: -76.000
#   F: -94.056
#   G: -112.868
#
# ================================================================================
# SOLVING FOR (1-m) EXPLANATION
# ================================================================================
#
# ================================================================================
# OPTIMAL (1-m) EXPLANATION FOUND!
# ================================================================================
#
# Minimum number of trade-offs: 3
#
# --------------------------------------------------------------------------------
# TRADE-OFFS:
# --------------------------------------------------------------------------------
#
#   Trade-off: (A, {C})
#     - Pro contribution [A]: +84.000
#     - Con contribution [C]: -76.000
#     - Total: +8.000
#     - Valid: True
#
#   Trade-off: (D, {F})
#     - Pro contribution [D]: +96.600
#     - Con contribution [F]: -94.056
#     - Total: +2.544
#     - Valid: True
#
#   Trade-off: (E, {G})
#     - Pro contribution [E]: +128.992
#     - Con contribution [G]: -112.868
#     - Total: +16.124
#     - Valid: True
# Explanation: {'type': '1-m', 'status': 'optimal', 'tradeoffs': [{'pro': 0, 'cons': [2], 'pro_contribution': 84.0, 'cons_contributions': {2: -76.0}, 'total': 8.0}, {'pro': 3, 'cons': [5], 'pro_contribution': 96.60000000000001, 'cons_contributions': {5: -94.05620000000015}, 'total': 2.5437999999998624}, {'pro': 4, 'cons': [6], 'pro_contribution': 128.992, 'cons_contributions': {6: -112.868}, 'total': 16.123999999999995}], 'num_tradeoffs': 3}
# ----------------------------------------

# %%
from script import find_explanation

record1 = [85, 81, 71, 69, 75, 81, 88]
record2 = [81, 81, 75, 63, 67, 88, 95]

# For (1-m) explanation
result = find_explanation(record1, record2, explanation_type="1-m")

# For (m-1) explanation
result = find_explanation(record1, record2, explanation_type="m-1")

# For hybrid explanation
result = find_explanation(record1, record2, explanation_type=["1-m", "m-1"])
